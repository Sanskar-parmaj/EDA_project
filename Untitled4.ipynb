# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanskar-parmaj/EDA_project/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-82f8cfab-d11f-4a7d-b44d-1393c997fd10" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-82f8cfab-d11f-4a7d-b44d-1393c997fd10">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.metrics as metrics
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("Salary Data.csv", encoding="latin-1")

# %%
df.columns = df.columns.str.strip().str.replace('ï»¿', '', regex=False)

# %%
df.shape
# Out:
# (373, 6)

# %%
df.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 373 entries, 0 to 374
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  373 non-null    float64
#  1   Gender               373 non-null    object
#  2   Education Level      373 non-null    object
#  3   Job Title            373 non-null    object
#  4   Years of Experience  373 non-null    float64
#  5   Salary               373 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 20.4+ KB

# %%
df.describe()
# Out:
#               Age  Years of Experience         Salary
# count  373.000000           373.000000     373.000000
# mean    37.431635            10.030831  100577.345845
# std      7.069073             6.557007   48240.013482
# min     23.000000             0.000000     350.000000
# 25%     31.000000             4.000000   55000.000000
# 50%     36.000000             9.000000   95000.000000
# 75%     44.000000            15.000000  140000.000000
# max     53.000000            25.000000  250000.000000

# %%
df.isnull().sum()
# Out:
# Age                    0
# Gender                 0
# Education Level        0
# Job Title              0
# Years of Experience    0
# Salary                 0
# dtype: int64

# %%
title_counts = df['Job Title'].value_counts()
min_count_threshold = 5
titles_to_keep = title_counts[title_counts >= min_count_threshold].index

df['Job Title_Grouped'] = np.where(
    df['Job Title'].isin(titles_to_keep),
    df['Job Title'],
    'Job Title_Other'
)

# %%
education_order = {
    "High School": 1,
    "Bachelor's": 2,  # Corrected key to match data
    "Master's": 3,    # Corrected key to match data
    "PhD": 4
}
df['Education_Rank'] = df['Education Level'].map(education_order)

# %%
df.drop(['Job Title', 'Education Level'], axis=1, inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(72)

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 301 entries, 0 to 371
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  301 non-null    float64
#  1   Gender               301 non-null    object
#  2   Years of Experience  301 non-null    float64
#  3   Salary               301 non-null    float64
#  4   Job Title_Grouped    301 non-null    object
#  5   Education_Rank       301 non-null    int64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 16.5+ KB

# %%
df_encoded = pd.get_dummies(df, columns=['Gender', 'Job Title_Grouped'], drop_first=True)

# Remove rows that had an unmapped Education Level (if any)
df_encoded.dropna(inplace=True)

# %%
num_cols = df.select_dtypes(include=["float64", "int64"]).columns.tolist()

for col in num_cols:
    plt.figure(figsize=(6,3))
    sns.boxplot(y=df[col])
    plt.show()
    plt.tight_layout()
    plt.pause(0.5)

# %%
for col in df.select_dtypes(include=["float64", "int64"]).columns:
  plt.figure(figsize=(12,3))
  sns.histplot(df[col], kde=True)
  plt.title(f"Distribution of {col}")
  plt.show()

# %%
for col in df.select_dtypes(include=["object", "category"]).columns:
  plt.figure(figsize=(10,3))
  sns.countplot(x=df[col])
  plt.title(f"Countplot of {col}")
  plt.xticks(rotation=45)
  plt.show()

# %%
sns.pairplot(df[num_cols])
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df[num_cols].corr(), annot=True, cmap="BrBG")
plt.title("Correlation Heatmap")
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df[num_cols] = scaler.fit_transform(df[num_cols])


print(df.head())
# Out:
#         Age  Gender  Years of Experience    Salary Job Title_Grouped  \
# 0 -0.807047    Male            -0.820390 -0.263402   Job Title_Other
# 1 -1.367419  Female            -1.123566 -0.780873   Job Title_Other
# 2  1.014161    Male             0.695493  0.978530   Job Title_Other
# 3 -0.246675  Female            -0.517213 -0.884367   Job Title_Other
# 4  1.994811    Male             1.453434  2.013473   Job Title_Other
#
#    Education_Rank
# 0       -0.779622
# 1        0.608935
# 2        1.997493
# 3       -0.779622
# 4        0.608935

# %%
Y = df_encoded['Salary']
# This drops 'Salary' and 'Years of Experience' and keeps everything else as features
X = df_encoded.drop(columns=['Salary', 'Years of Experience'])

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

print("Data Split Complete:")
print(f"X_train size: {X_train.shape[0]} samples")
print(f"X_test size: {X_test.shape[0]} samples\n")
# Out:
# Data Split Complete:
# X_train size: 240 samples
# X_test size: 61 samples

# %%
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
model.score(X_train,Y_train)
# Out:
# 0.8999672810987269

# %%
Y_pred = model.predict(X_test)

# %%
print("--- Model Performance on Test Data ---")

# R-squared (R²) Score
r2 = r2_score(Y_test, Y_pred)

# Root Mean Squared Error (RMSE)
rmse = np.sqrt(mean_squared_error(Y_test, Y_pred))

print(f"R-squared (R²): {r2:.4f}")
print(f"Root Mean Squared Error (RMSE): ${rmse:,.2f}")
print("\n")
# Out:
# --- Model Performance on Test Data ---
# R-squared (R²): 0.8852
# Root Mean Squared Error (RMSE): $15,354.39

# %%
predicted_train=model.fit(X_train,Y_train).predict(X_train)
rmse_train=np.sqrt(metrics.mean_squared_error(Y_train,predicted_train))
print('RMSE on train dataset : ', rmse_train)
# Out:
# RMSE on train dataset :  15510.889309583567

# %%
#RMSE on testing data

predicted_test=model.fit(X_train,Y_train).predict(X_test)
rmse_test=np.sqrt(metrics.mean_squared_error(Y_test,predicted_test))
print('RMSE on test dataset : ', rmse_test)
# Out:
# RMSE on test dataset :  15354.391125948338

# %%
# Intercept and Coefficient Interpretation (The Linear Equation)
intercept = model.intercept_
coefficient = model.coef_[0]

print("--- Model Interpretation ---")
print(f"Intercept (β₀): ${intercept:,.2f}")
print(f"Coefficient (β₁): ${coefficient:,.2f}")
print(f"\nLinear Equation: Salary = ${intercept:,.2f} + (${coefficient:,.2f} * Years of Experience)")
# Out:
# --- Model Interpretation ---
# Intercept (β₀): $-126,603.21
# Coefficient (β₁): $5,046.80
#
# Linear Equation: Salary = $-126,603.21 + ($5,046.80 * Years of Experience)
